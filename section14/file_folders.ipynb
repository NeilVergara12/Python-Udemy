# %%
pwd
# Out:
# 'c:\\Users\\Grace\\Downloads\\Python-Udemy\\section14'

# %%
f = open('practice.txt','w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Grace\\Downloads\\Python-Udemy\\section14'

# %%
os.listdir('C:\\Users')
# Out:
# ['All Users', 'Default', 'Default User', 'desktop.ini', 'Grace', 'Public']

# %%
import shutil

# %%
shutil.move('practice.txt','c:\\Users\\Grace')
# Out:
# 'c:\\Users\\Grace\\practice.txt'

# %%
os.listdir('c:\\Users\\Grace')
# Out:
# ['.anaconda',
#  '.conda',
#  '.continuum',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.lesshst',
#  '.python_history',
#  '.vscode',
#  'anaconda3',
#  'anaconda_projects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'CrossDevice',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'My Python',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{8151a053-e897-11f0-af76-fe9bc6674ad9}.TM.blf',
#  'NTUSER.DAT{8151a053-e897-11f0-af76-fe9bc6674ad9}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{8151a053-e897-11f0-af76-fe9bc6674ad9}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'practice.txt',
#  'PrintHood',
#  'pythonUdemy',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Videos']

# %%
shutil.move('c:\\Users\\Grace\\practice.txt',os.getcwd())
# Out:
# 'c:\\Users\\Grace\\Downloads\\Python-Udemy\\section14\\practice.txt'

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['collections_module.ipynb', 'file_folders.ipynb', 'practice.txt']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['collections_module.ipynb', 'file_folders.ipynb']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Grace\\Downloads\\Python-Udemy\\section14'

# %%
file_path = 'c:\\Users\\Grace\\Downloads\\Python-Udemy\\Complete-Python-3-Bootcamp-master1\\12-Advanced Python Modules\\Example_Top_Level'

# %%
for folder, sub_folders,files in os.walk(file_path):
    print(f"Currently looking at {folder}")
    print('\n')
    print('The subfolders are: ')
    for sub_fold in sub_folders:
        print(f"\t Subfolder: {sub_fold}")

    print('\n')
    print("the files are: ")
    for f in files:
        print(f"\t File: {f}")
    print('\n')
# Out:
# Currently looking at c:\Users\Grace\Downloads\Python-Udemy\Complete-Python-3-Bootcamp-master1\12-Advanced Python Modules\Example_Top_Level
#
#
# The subfolders are:
# 	 Subfolder: Mid-Example-One
#
#
# the files are:
# 	 File: Mid-Example.txt
#
#
# Currently looking at c:\Users\Grace\Downloads\Python-Udemy\Complete-Python-3-Bootcamp-master1\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One
#
#
# The subfolders are:
# 	 Subfolder: Bottom-Level-One
# 	 Subfolder: Bottom-Level-Two
#
#
# the files are:
# 	 File: Mid-Level-Doc.txt
#
#
# Currently looking at c:\Users\Grace\Downloads\Python-Udemy\Complete-Python-3-Bootcamp-master1\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One\Bottom-Level-One
#
#
# The subfolders are:
#
#
# the files are:
# 	 File: One_Text.txt
#
#
# Currently looking at c:\Users\Grace\Downloads\Python-Udemy\Complete-Python-3-Bootcamp-master1\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One\Bottom-Level-Two
#
#
# The subfolders are:
#
# ...
