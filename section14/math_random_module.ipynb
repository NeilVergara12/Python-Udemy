# %%
import math

# %%
value = 4.35

# %%
math.floor(value)
# Out:
# 4

# %%
math.ceil(value)
# Out:
# 5

# %%
round(4.35)
# Out:
# 4

# %%
round(4.5)
# Out:
# 4

# %%
round(5.5)
# Out:
# 6

# %%
math.pi
# Out:
# 3.141592653589793

# %%
from math import pi

# %%
pi
# Out:
# 3.141592653589793

# %%
math.inf
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %% [markdown]
# Numpy

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.log(math.e)
# Out:
# 1.0

# %%
math.log(100,10)
# Out:
# 2.0

# %%
10**2
# Out:
# 100

# %%
math.sin(10)
# Out:
# -0.5440211108893698

# %%
math.degrees(pi/2)
# Out:
# 90.0

# %%
math.radians(180)
# Out:
# 3.141592653589793
