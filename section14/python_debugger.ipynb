# %%
x = [1, 2, 3] 
y = 2 
z = 3

# result y + z 
# print(result)
# result2 = x + y y
# print(y)
# print(result2)

# %%
import pdb

# %%
x = [1, 2, 3] 
y = 2 
z = 3

result_one = y+z

pdb.set_trace()

result_two = y+x
# Out:
# > c:\users\grace\appdata\local\temp\ipykernel_2276\1645175416.py(7)<module>()
#
# [1, 2, 3]
# 5
# 2
# [1, 2, 3]
