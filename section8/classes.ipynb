# %%
mylist = [1,2,3]

# %%
myset = set()

# %%
type(myset)
# Out:
# set

# %%
type(mylist)
# Out:
# list

# %%
class Sample():
    pass

# %%
my_sample = Sample()

# %%
type(my_sample)
# Out:
# __main__.Sample

# %%
class Dog():

    def __init__(self,breed):
        
        self.breed= breed

# %%
my_dog = Dog(breed='Lab')

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.breed
# Out:
# 'Lab'

# %%
class Dog():

    def __init__(self,mybreed):

        # Attributes
        # We take in the argument
        # Assign it usinng selt.attribute_name
        self.my_attribute = mybreed

# %%
my_dog = Dog(mybreed='Huskies')

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.my_attribute
# Out:
# 'Huskies'

# %%
class Dog():

    def __init__(self,breed,name,spots):

        # Attributes
        # We take in the argument
        # Assign it usinng selt.attribute_name
        self.breed = breed
        self.name = name

        # Expect boolean True/False
        self.spots = spots

# %%
my_dog = Dog(breed='Lab', name='Sammy' ,spots=False)

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.breed
# Out:
# 'Lab'

# %%
my_dog.name
# Out:
# 'Sammy'

# %%
my_dog.spots
# Out:
# False

# %% [markdown]
# CAMEL CASE FOR CLASS

# %%
class Dog():

    # CLASS OBJECT ATTRIBUTE
    # SAME FOR AN INSTANCE OF A CLASS
    Species = 'mammal'

    def __init__(self,breed,name,spots):

        # Attributes
        # We take in the argument
        # Assign it usinng selt.attribute_name
        self.breed = breed
        self.name = name

        # Expect boolean True/False
        self.spots = spots

# %%
my_dog = Dog(breed='Lab', name='Sam' ,spots=False)

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.Species
# Out:
# 'mammal'

# %%
class Dog():

    # CLASS OBJECT ATTRIBUTE
    # SAME FOR AN INSTANCE OF A CLASS
    Species = 'mammal'

    def __init__(self,breed,name):

        # Attributes
        # We take in the argument
        # Assign it usinng selt.attribute_name
        self.breed = breed
        self.name = name

    # OPERATIONS/Actions ---> Methods
    def bark(self,number):
        print("WOOF! My name is {} and the number is {}".format(self.name,number))

# %%
my_dog = Dog('Lab','Frankie')

# %%
type(my_dog)
# Out:
# __main__.Dog

# %%
my_dog.Species
# Out:
# 'mammal'

# %%
my_dog.name
# Out:
# 'Frankie'

# %%
my_dog.bark(10)
# Out:
# WOOF! My name is Frankie and the number is 10

# %%
class Circle():
    # CLASS OBJECT ATTRIBUTE
    pi = 3.14

    def __init__(self,radius=1):
        
        self.radius = radius
        self.area = radius*radius*self.pi
    # Method
    def get_circumference(self):
        return self.radius * self.pi *2

# %%
my_circle = Circle(30)

# %%
my_circle.pi
# Out:
# 3.14

# %%
my_circle.radius
# Out:
# 30

# %%
my_circle.area
# Out:
# 2826.0

# %%
my_circle.get_circumference()
# Out:
# 188.4

# %% [markdown]
# INHERITANCE AND POLYMORPHISM

# %%
class Animal():

    def __init__(self):
        print("ANIMAL CREATED")

    def who_am_i(self):
        print("I am an animal")

    def eat(self):
        print("I am eating")

# %%
class Dog(Animal):

    def __init__(self):
        Animal.__init__(self)
        print("DOg Created")

    def eat(self):
        print("I am a dog eating")

    def bark(self):
        print("WOOF!")

# %%
mydog = Dog()
# Out:
# ANIMAL CREATED
# DOg Created

# %%
mydog.eat()
# Out:
# I am a dog eating

# %%
mydog.who_am_i()
# Out:
# I am an animal

# %%
mydog.bark()
# Out:
# WOOF!

# %%
myanimal = Animal()
# Out:
# ANIMAL CREATED

# %%
myanimal.who_am_i()
# Out:
# I am an animal

# %% [markdown]
# POLYMORPHISM

# %%
class Dog():
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name + " says woof!"

# %%
class Cat():
    def __init__(self, name):
        self.name = name

    def speak(self):
        return self.name + " says meow!"

# %%
niko = Dog("niko")
felix = Cat("felix")

# %%
print(niko.speak())
# Out:
# niko says woof!

# %%
print(felix.speak())
# Out:
# felix says meow!

# %%
for pet in [niko, felix]:
    print(type(pet))
    print(pet.speak())
# Out:
# <class '__main__.Dog'>
# niko says woof!
# <class '__main__.Cat'>
# felix says meow!

# %%
def pet_speak(pet):
    print(pet.speak())

# %%
pet_speak(niko)
# Out:
# niko says woof!

# %%
pet_speak (felix)
# Out:
# felix says meow!

# %%
class Animal():

    def __init__(self, name):
        self.name = name

    def speak(self):
        raise NotImplementedError("Subclass must implement this abstract method")

# %%
myanimal = Animal('Fred')

# %%
class Dog (Animal):
    def speak(self):
        return self.name+ " says woof!"

# %%
class Cat (Animal):
    def speak(self):
        return self.name+ " says meow!"

# %%
fid0 = Dog("Fido")

# %%
isis = Cat("Isis")

# %%
print(fid0.speak())
# Out:
# Fido says woof!

# %%
print(isis.speak())
# Out:
# Isis says meow!

# %% [markdown]
# SPECIAL (MAGIC/DUNKER) METHOD

# %%
mylist = [1,2,3]

# %%
len(mylist)
# Out:
# 3

# %%
class Sample(): 
    pass

# %%
mysample = Sample()

# %%
print(mysample)

# %%
print(mylist)
# Out:
# [1, 2, 3]

# %%
class Book():

    def __init__(self, title, author, pages):
    
        self.title = title
        self.author = author
        self.pages = pages

    def __str__(self):
        return f"{self.title} by {self.author}"
    
    def __len__(self):
        return self.pages
    
    def __del__(self):
        print("A book object has been deleted")

# %%
b = Book('Python rocks', 'Jose', 200)

# %%
print(b)
# Out:
# Python rocks by Jose

# %%
print(b)
# Out:
# Python rocks by Jose

# %%
del b
# Out:
# A book object has been deleted

# %%
str(b)
# Out:
# 'Python rocks by Jose'

# %%
len(b)
# Out:
# 200
