# %%
2<3
# Out:
# True

# %%
1<2>3
# Out:
# False

# %%
1<2 and 2<3
# Out:
# True

# %%
'h' =='h' and 2==2
# Out:
# True

# %%
100==1 or 2==200
# Out:
# False

# %%
1==1
# Out:
# True

# %%
not(1==1)
# Out:
# False

# %%
not 400 > 5000
# Out:
# True

# %%
2<4
# Out:
# True

# %%
a=12

# %%
b=a-10

# %%
a>b
# Out:
# True

# %%
12!=12
# Out:
# False

# %%
2<3>10
# Out:
# False

# %%
2<=3>=1
# Out:
# True
