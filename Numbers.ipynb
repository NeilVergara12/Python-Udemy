# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %%
7/4
# Out:
# 1.75

# %%
7%4
# Out:
# 3

# %%
50%5
# Out:
# 0

# %%
23 % 2
# Out:
# 1

# %%
20%2
# Out:
# 0

# %%
2**3
# Out:
# 8

# %%
2+10*10+3
# Out:
# 105

# %%
2+10*10+3
# Out:
# 105

# %%
(2+10)*(10+3)
# Out:
# 156

# %%
50*3-50
# Out:
# 100

# %%
6**6
# Out:
# 46656

# %%
6^6
# Out:
# 0

# %%
30+*6
# Out:
#   Cell In[16], line 1
#     30+*6
#        ^
# SyntaxError: invalid syntax

# %%
6+6+6+6+6
# Out:
# 30

# %%
6*6
# Out:
# 36

# %%
1/3
# Out:
# 0.3333333333333333

# %%
4*(6+5)
# Out:
# 44

# %%
4*6+5
# Out:
# 29

# %%
4+6*5
# Out:
# 34

# %%
10**2 + 1/2 - 1/4
# Out:
# 100.25
