# %%
def name_of_function(Neil):
    print("Hello" +Neil)

# %%
print (name_of_function)
# Out:
# <function name_of_function at 0x00000209B3502B60>

# %%
name_of_function
# Out:
# <function __main__.name_of_function(Neil)>

# %%
name_of_function("Neil")
# Out:
# HelloNeil
