# %%
hungry = False
if hungry:
    print('FEED ME')
else:
    print('IM NOT HUNGRY')
# Out:
# IM NOT HUNGRY

# %%
loc = 'Auto Shop'
if loc == 'Auto Shop':
    print("Cars are cool!")
elif loc == 'Bank':
    print("Money is cool")
elif loc == 'Store':
    print("Welcome to the store!")
else:
    print("I do not know much.")
# Out:
# Cars are cool!

# %%
name = 'Neil'

if name == 'Neil':
    print('Hello Neil')
elif name == 'Neil':
    print('Hello Neil')
else:
    print('What is your name?')
# Out:
# Hello Neil
